# %%
import pandas as pd

# %%
df1 = pd.read_csv("bracket.csv")
df2 = pd.read_csv("support.csv")

# %%
df1
# Out:
#       Point ID      area  equilibrium_x  equilibrium_y  equilibrium_z  \
# 0            0  0.000344      -0.251486       0.163675       0.784635
# 1            1  0.000344       0.071360       0.008623       0.173197
# 2            2  0.000344      -0.746264      -0.201733       3.363420
# 3            3  0.000344      -0.028377      -0.076603       0.329175
# 4            4  0.000344       0.482235       0.416034       1.824810
# ...        ...       ...            ...            ...            ...
# 1019      1019  0.000344      -0.040415      -0.066814       0.298626
# 1020      1020  0.000344      -1.236700      -0.355819       4.374950
# 1021      1021  0.000344      -0.016284      -0.138893      -0.062788
# 1022      1022  0.000344       0.016149      -0.002588       0.036327
# 1023      1023  0.000344       0.070143       0.070380       0.344993
#
#       lambda_equilibrium_x  lambda_equilibrium_y  lambda_equilibrium_z  \
# 0                 0.052394              0.052394              0.052394
# 1                 0.016290              0.016290              0.016290
# 2                 0.008252              0.008252              0.008252
# 3                 0.018611              0.018611              0.018611
# 4                 0.020383              0.020383              0.020383
# ...                    ...                   ...                   ...
# 1019              0.078456              0.078456              0.078456
# 1020              0.001889              0.001889              0.001889
# 1021              0.026977              0.026977              0.026977
# 1022              0.067147              0.067147              0.067147
# 1023              0.073573              0.073573              0.073573
#
#       lambda_stress_disp_xx  lambda_stress_disp_xy  ...      u__y      u__z  \
# 0                  0.052394               0.052394  ... -0.007181  1.006230
# 1                  0.016290               0.016290  ... -0.003758  0.353709
# 2                  0.008252               0.008252  ...  0.010462  0.937211
# 3                  0.018611               0.018611  ...  0.001865  0.359593
# 4                  0.020383               0.020383  ... -0.011201  0.929551
# ...                     ...                    ...  ...       ...       ...
# 1019               0.078456               0.078456  ... -0.004210  0.942743
# 1020               0.001889               0.001889  ...  0.006334  0.440217
# 1021               0.026977               0.026977  ... -0.000128  0.005694
# 1022               0.067147               0.067147  ...  0.000217  0.055439
# 1023               0.073573               0.073573  ...  0.003872  0.935004
#
#              v      v__x      v__y      v__z         w      w__x      w__y  \
# 0    -0.003049 -0.000803 -0.009173 -0.049126 -0.833493 -1.011120  0.055441
# 1     0.003703  0.005836  0.013656 -0.068493 -0.092695 -0.341531  0.068726
# 2     0.009217  0.005044 -0.005448  0.118085 -0.785255 -0.939718 -0.118175
# 3     0.004075  0.007362  0.019128 -0.053936 -0.100851 -0.356327  0.053807
# 4    -0.009067 -0.009221  0.007043  0.101570 -0.707907 -0.933956 -0.102877
# ...        ...       ...       ...       ...       ...       ...       ...
# 1019 -0.002205 -0.001717 -0.001339 -0.074612 -0.670025 -0.946529  0.074462
# 1020  0.004629  0.009301 -0.023307  0.052447 -0.141641 -0.439853 -0.052425
# 1021 -0.000345  0.000052 -0.000037  0.005122 -0.000361 -0.006891 -0.006331
# 1022 -0.001082 -0.002340  0.003265  0.020642 -0.002274 -0.045050 -0.019927
# 1023  0.002126  0.000738  0.002052 -0.104938 -0.786146 -0.947565  0.112187
#
#           w__z
# 0     0.002957
# 1     0.013530
# 2    -0.000379
# 3     0.018867
# 4     0.003875
# ...        ...
# 1019 -0.000509
# 1020 -0.024369
# 1021 -0.000049
# 1022  0.003405
# 1023  0.000385
#
# [1024 rows x 70 columns]

# %%
df2
# Out:
#       Point ID      area  equilibrium_x  equilibrium_y  equilibrium_z  \
# 0            0  0.000512       0.002265       0.004259      -0.000279
# 1            1  0.000512       0.022930      -0.004658      -0.019343
# 2            2  0.000512      -0.018643       0.001971      -0.040661
# 3            3  0.000512       0.010333      -0.003976      -0.004429
# 4            4  0.000512       0.043949      -0.010795      -0.037110
# ...        ...       ...            ...            ...            ...
# 2043      2043  0.000512       0.000060       0.008538      -0.003336
# 2044      2044  0.000512       0.001526      -0.001806      -0.002993
# 2045      2045  0.000512      -0.000532      -0.000198      -0.010908
# 2046      2046  0.000512      -0.002991       0.000499      -0.013338
# 2047      2047  0.000512      -0.000960      -0.001135      -0.006335
#
#       lambda_equilibrium_x  lambda_equilibrium_y  lambda_equilibrium_z  \
# 0                 0.124398              0.124398              0.124398
# 1                 0.012237              0.012237              0.012237
# 2                 0.062030              0.062030              0.062030
# 3                 0.051027              0.051027              0.051027
# 4                 0.045953              0.045953              0.045953
# ...                    ...                   ...                   ...
# 2043              0.074899              0.074899              0.074899
# 2044              0.124258              0.124258              0.124258
# 2045              0.017862              0.017862              0.017862
# 2046              0.112934              0.112934              0.112934
# 2047              0.073990              0.073990              0.073990
#
#       lambda_stress_disp_xx  lambda_stress_disp_xy  ...      u__y      u__z  \
# 0                  0.124398               0.124398  ... -0.000059 -0.000201
# 1                  0.012237               0.012237  ... -0.000444 -0.000372
# 2                  0.062030               0.062030  ... -0.000441 -0.000200
# 3                  0.051027               0.051027  ...  0.000464 -0.000639
# 4                  0.045953               0.045953  ... -0.000514  0.002599
# ...                     ...                    ...  ...       ...       ...
# 2043               0.074899               0.074899  ...  0.000214 -0.000334
# 2044               0.124258               0.124258  ... -0.000191 -0.000361
# 2045               0.017862               0.017862  ...  0.000279 -0.000472
# 2046               0.112934               0.112934  ... -0.000632 -0.001389
# 2047               0.073990               0.073990  ...  0.000157 -0.000325
#
#              v      v__x      v__y      v__z         w      w__x      w__y  \
# 0    -0.000339  0.000059  0.000005  0.000027  0.000318  0.000185 -0.000032
# 1    -0.000386  0.000487  0.000047  0.000056  0.000293  0.000263  0.000108
# 2    -0.000245  0.000904  0.000251 -0.000084  0.000300 -0.000166 -0.000192
# 3    -0.000398 -0.000528  0.000018  0.000194  0.000330  0.000673 -0.000090
# 4    -0.000406 -0.000430  0.000243 -0.001154  0.000411 -0.000560 -0.000033
# ...        ...       ...       ...       ...       ...       ...       ...
# 2043 -0.000313 -0.000217  0.000010 -0.000055  0.000331  0.000244  0.000024
# 2044 -0.000303  0.000177 -0.000002  0.000060  0.000329  0.000381 -0.000065
# 2045 -0.000288 -0.000279 -0.000026 -0.000135  0.000319  0.000500  0.000115
# 2046 -0.000399  0.000143 -0.000174  0.000372  0.000291 -0.000505  0.000131
# 2047 -0.000302 -0.000155 -0.000013 -0.000032  0.000351  0.000369  0.000023
#
#           w__z
# 0     0.000026
# 1    -0.000014
# 2     0.000648
# 3    -0.000028
# 4    -0.000667
# ...        ...
# 2043 -0.000011
# 2044  0.000004
# 2045  0.000019
# 2046 -0.000200
# 2047 -0.000003
#
# [2048 rows x 70 columns]

# %%
merged_df = pd.concat([df1, df2], ignore_index = True)

# %%
merged_df
# Out:
#       Point ID      area  equilibrium_x  equilibrium_y  equilibrium_z  \
# 0            0  0.000344      -0.251486       0.163675       0.784635
# 1            1  0.000344       0.071360       0.008623       0.173197
# 2            2  0.000344      -0.746264      -0.201733       3.363420
# 3            3  0.000344      -0.028377      -0.076603       0.329175
# 4            4  0.000344       0.482235       0.416034       1.824810
# ...        ...       ...            ...            ...            ...
# 3067      2043  0.000512       0.000060       0.008538      -0.003336
# 3068      2044  0.000512       0.001526      -0.001806      -0.002993
# 3069      2045  0.000512      -0.000532      -0.000198      -0.010908
# 3070      2046  0.000512      -0.002991       0.000499      -0.013338
# 3071      2047  0.000512      -0.000960      -0.001135      -0.006335
#
#       lambda_equilibrium_x  lambda_equilibrium_y  lambda_equilibrium_z  \
# 0                 0.052394              0.052394              0.052394
# 1                 0.016290              0.016290              0.016290
# 2                 0.008252              0.008252              0.008252
# 3                 0.018611              0.018611              0.018611
# 4                 0.020383              0.020383              0.020383
# ...                    ...                   ...                   ...
# 3067              0.074899              0.074899              0.074899
# 3068              0.124258              0.124258              0.124258
# 3069              0.017862              0.017862              0.017862
# 3070              0.112934              0.112934              0.112934
# 3071              0.073990              0.073990              0.073990
#
#       lambda_stress_disp_xx  lambda_stress_disp_xy  ...      u__y      u__z  \
# 0                  0.052394               0.052394  ... -0.007181  1.006230
# 1                  0.016290               0.016290  ... -0.003758  0.353709
# 2                  0.008252               0.008252  ...  0.010462  0.937211
# 3                  0.018611               0.018611  ...  0.001865  0.359593
# 4                  0.020383               0.020383  ... -0.011201  0.929551
# ...                     ...                    ...  ...       ...       ...
# 3067               0.074899               0.074899  ...  0.000214 -0.000334
# 3068               0.124258               0.124258  ... -0.000191 -0.000361
# 3069               0.017862               0.017862  ...  0.000279 -0.000472
# 3070               0.112934               0.112934  ... -0.000632 -0.001389
# 3071               0.073990               0.073990  ...  0.000157 -0.000325
#
#              v      v__x      v__y      v__z         w      w__x      w__y  \
# 0    -0.003049 -0.000803 -0.009173 -0.049126 -0.833493 -1.011120  0.055441
# 1     0.003703  0.005836  0.013656 -0.068493 -0.092695 -0.341531  0.068726
# 2     0.009217  0.005044 -0.005448  0.118085 -0.785255 -0.939718 -0.118175
# 3     0.004075  0.007362  0.019128 -0.053936 -0.100851 -0.356327  0.053807
# 4    -0.009067 -0.009221  0.007043  0.101570 -0.707907 -0.933956 -0.102877
# ...        ...       ...       ...       ...       ...       ...       ...
# 3067 -0.000313 -0.000217  0.000010 -0.000055  0.000331  0.000244  0.000024
# 3068 -0.000303  0.000177 -0.000002  0.000060  0.000329  0.000381 -0.000065
# 3069 -0.000288 -0.000279 -0.000026 -0.000135  0.000319  0.000500  0.000115
# 3070 -0.000399  0.000143 -0.000174  0.000372  0.000291 -0.000505  0.000131
# 3071 -0.000302 -0.000155 -0.000013 -0.000032  0.000351  0.000369  0.000023
#
#           w__z
# 0     0.002957
# 1     0.013530
# 2    -0.000379
# 3     0.018867
# 4     0.003875
# ...        ...
# 3067 -0.000011
# 3068  0.000004
# 3069  0.000019
# 3070 -0.000200
# 3071 -0.000003
#
# [3072 rows x 70 columns]

# %%
merged_df.columns
# Out:
# Index(['Point ID', 'area', 'equilibrium_x', 'equilibrium_y', 'equilibrium_z',
#        'lambda_equilibrium_x', 'lambda_equilibrium_y', 'lambda_equilibrium_z',
#        'lambda_stress_disp_xx', 'lambda_stress_disp_xy',
#        'lambda_stress_disp_xz', 'lambda_stress_disp_yy',
#        'lambda_stress_disp_yz', 'lambda_stress_disp_zz', 'Points_0',
#        'Points_1', 'Points_2', 'Points_Magnitude', 'pred_equilibrium_x',
#        'pred_equilibrium_y', 'pred_equilibrium_z', 'pred_stress_disp_xx',
#        'pred_stress_disp_xy', 'pred_stress_disp_xz', 'pred_stress_disp_yy',
#        'pred_stress_disp_yz', 'pred_stress_disp_zz', 'sdf', 'sigma_xx',
#        'sigma_xx__x', 'sigma_xy', 'sigma_xy__x', 'sigma_xy__y', 'sigma_xz',
#        'sigma_xz__x', 'sigma_xz__z', 'sigma_yy', 'sigma_yy__y', 'sigma_yz',
#        'sigma_yz__y', 'sigma_yz__z', 'sigma_zz', 'sigma_zz__z',
#        'stress_disp_xx', 'stress_disp_xy', 'stress_disp_xz', 'stress_disp_yy',
#        'stress_disp_yz', 'stress_disp_zz', 'true_equilibrium_x',
#        'true_equilibrium_y', 'true_equilibrium_z', 'true_stress_disp_xx',
#        'true_stress_disp_xy', 'true_stress_disp_xz', 'true_stress_disp_yy',
#        'true_stress_disp_yz', 'true_stress_disp_zz', 'u', 'u__x', 'u__y',
#        'u__z', 'v', 'v__x', 'v__y', 'v__z', 'w', 'w__x', 'w__y', 'w__z'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(figsize = (12,12))
ax = fig.add_subplot(projection = '3d')

scatter = ax.scatter(merged_df['Points_0'],merged_df['Points_1'],merged_df['Points_2'], c = merged_df['w'], cmap = 'rainbow', marker='o', s =10)

ax.set_xlabel('x_axis')
ax.set_ylabel('y_axis')
ax.set_zlabel('zaxis')

fig.colorbar(scatter, ax=ax, label = 'w')

# %%
fig = plt.figure(figsize = (12,12))
ax = fig.add_subplot(projection = '3d')

scatter = ax.scatter(merged_df['Points_0'],merged_df['Points_1'],merged_df['Points_2'], c = merged_df['sigma_xx'], cmap = 'rainbow', marker='o', s =10)

ax.set_xlabel('x_axis')
ax.set_ylabel('y_axis')
ax.set_zlabel('zaxis')

fig.colorbar(scatter, ax=ax, label = 'sigma_xx')
